# %%
setwd('C:/Users/Falco/Desktop/directory/Predicting-wildlife-reservoirs-of-Flaviviruses')

# %%
options(warn=-1)
#install.packages(c('gbm', 'dplyr','dismo', 'caret',
#                  'sjplot', 'skmisc','ggplot2'), repos='http://cran.us.r-project.org')
library(gbm)
library(dplyr)
library(dismo)
library(caret)
library(sjPlot)
library(sjmisc)
library(ggplot2)
library(raster)
library(plyr)
library(data.table)
# Out:
# Loading required package: survival
# Loading required package: lattice
# Loading required package: splines
# Loading required package: parallel
# Loaded gbm 2.1.3
#
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Loading required package: raster
# Loading required package: sp
#
# Attaching package: 'raster'
#
# The following object is masked from 'package:dplyr':
#
#     select
#
# Loading required package: ggplot2
#
# Attaching package: 'caret'
#
# The following object is masked from 'package:survival':
#
#     cluster
#
#
# Attaching package: 'sjmisc'
#
# The following object is masked from 'package:raster':
#
#     trim
#
# ------------------------------------------------------------------------------
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
# ------------------------------------------------------------------------------
#
# Attaching package: 'plyr'
#
# The following objects are masked from 'package:dplyr':
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# Attaching package: 'data.table'
#
# The following object is masked from 'package:raster':
#
#     shift
#
# The following objects are masked from 'package:dplyr':
#
#     between, first, last

# %%
#model.data = read.csv("Outputs/model_data.csv")
model.data = read.csv('Outputs/dataGroup6.csv')

# %%
#names(model.data)

# %%
model.data$Class = factor(model.data$Class, levels = levels(model.data$Class))
model.data$Order_y = factor(model.data$Order, levels = levels(model.data$Order))
model.data$Family_y = factor(model.data$Family, levels = levels(model.data$Family))
model.data$MatchHost = factor(model.data$MatchHost, levels = levels(model.data$MatchHost))
model.data$IUCN.Status = factor(model.data$IUCN.Status, levels = levels(model.data$IUCN.Status))
model.data$Diet_Certainty = factor(model.data$Diet_Certainty, levels = levels(model.data$Diet_Certainty))
model.data$Group6Binary2 <- ifelse(model.data$Group6Binary==1,'host','nonhost')
model.data$Group6Binary2 <- as.factor(model.data$Group6Binary2)
outcomeName <- 'Group6Binary2'

# %%
## Read in the raster data
landuse <- raster("D:/lust/lus.tif",package="raster")
## Extract attribute information for the categories from the raster layer, and convert into dataframe
LanduseAttributeTable <- ldply(landuse@data@attributes, data.frame)
#head(LanduseAttributeTable)

# %%
## Read in the raster data
Livestock <- raster("D:/lvstdt/lvstd.tif",package="raster")
## Extract attribute information for the categories from the raster layer, and convert into dataframe
LivestockAttributeTable <- ldply(Livestock@data@attributes, data.frame)
#LivestockAttributeTable

# %%
## Read in the raster data
Slope <- raster("D:/slpt/slp.tif",package="raster")
## Extract attribute information for the categories from the raster layer, and convert into dataframe
SlopeAttributeTable <- ldply(Slope@data@attributes, data.frame)
#SlopeAttributeTable

# %%
model.data = merge(model.data, LanduseAttributeTable, by.x = 'LandUse_majority', by.y = 'Value', all.x = TRUE)   
model.data = merge(model.data, LivestockAttributeTable, by.x = 'Livestock_majority', by.y = 'Value', all.x = TRUE)  
model.data = merge(model.data, SlopeAttributeTable, by.x = 'Slope_majority', by.y = 'Value', all.x = TRUE)

# %%
unique(model.data$LandUse_collapsed)
# Out:
#  [1] Undefined                Forest                   Urban
#  [4] Agriculture              Grassland                Sparsely vegetated areas
#  [7] Bare areas               Shurbs                   Wetlands
# [10] Open water
# 10 Levels: Agriculture Bare areas Forest Grassland Open water ... Wetlands

# %%
table(model.data$SLP_DS)
# Out:
#     > 45 0 to 0.5 0.5 to 2 16 to 30   2 to 5 30 to 45   5 to 8  8 to 16
#      550        0     2176     2366     1971      453      353       48
#  no data    Water
#      220        9

# %%
write.csv(model.data, 'Outputs/PartialDependence2/Group6Data_forPartial.csv')

# %%
habitats = c("Forest","Savanna","Shrubland","Grassland","Wetlands","Rocky.areas","Caves.and.Subterranean.Habitats","Desert",
            "Marine.Neritic","Marine.Oceanic","Marine.Deep.Ocean.Floor","Marine.Intertidal","Marine.Coastal.Supratidal", 
            "Artificial.Terrestrial","Artificial.Aquatic","Introduced.Vegetation","Other","Unknown")

predictorsNames = c("Bio12_majority", "Bio12_max", "Bio12_mean", "Bio12_min", "Bio12_range",
                    "Bio12_std", "Bio1_majority", "Bio1_max", "Bio1_mean", "Bio1_min", "Bio1_range", "Bio1_std", "Bio3_majority",
                    "Bio3_max", "Bio3_mean", "Bio3_min", "Bio3_range", "Bio3_std", "Crops_majority",
                    "HuPop_majority", "HuPop_max", "HuPop_mean", "HuPop_min", "HuPop_range",
                    "HuPop_std", "LandUse_majority", "Livestock_majority", "Mosquitoes_majority", "Mosquitoes_max",
                    "Mosquitoes_mean", "Slope_mean", "Slope_min", "Slope_range", "Slope_std",
                    "Ticks_majority", "Ticks_mean", "Ticks_min", "bdiversity_majority", "bdiversity_max",
                    "bdiversity_mean", "bdiversity_min", "bdiversity_range", "bdiversity_std",
                    "centroidY", "maxlat", "mdiversity_majority", "mdiversity_max", "mdiversity_mean",
                    "mdiversity_min", "mdiversity_range", "mdiversity_std", "minlat",
                    "minlong", "Mosquitoes_min_log", "Mosquitoes_range_log", "Mosquitoes_std_log",
                    "Shape_Area_log", "Shape_Length_log", "Slope_majority_log", "Slope_max_log",
                    "Ticks_max_log", "Ticks_range_log", "Ticks_std_log", "centroidX_log", "maxlong_log",
                    "MaxDiet", "ForStrategy", "ActivityTime","Body_Temperature", "IUCN.Status",
                    "Population.trend", "Data.Richness", "BodyMass_ln", "Metabolic_Rate_ln", "Habitat_Breadth_sqrt",
                    "PubmedHits_ln",'HuPop_mean_log',
                    'Class','Family','Order','SLP_DS',
                    'PTEROPODIDAE', 'BOVIDAE', 'CERVIDAE', 'ATELIDAE', 'PHYLLOSTOMIDAE',
       'FURIPTERIDAE', 'SORICIDAE', 'HIPPOSIDERIDAE', 'ANTILOCAPRIDAE',
       'VESPERTILIONIDAE', 'ERINACEIDAE', 'MOLOSSIDAE', 'SUIDAE',
       'EMBALLONURIDAE', 'CALLITRICHIDAE', 'CAMELIDAE', 'MEGADERMATIDAE',
       'TAYASSUIDAE', 'RHINOCEROTIDAE', 'NATALIDAE', 'CERCOPITHECIDAE',
       'HIPPOPOTAMIDAE', 'TALPIDAE', 'CRASEONYCTERIDAE', 'EQUIDAE',
       'GIRAFFIDAE', 'TRAGULIDAE', 'MORMOOPIDAE', 'MOSCHIDAE',
       'MYSTACINIDAE', 'MYZOPODIDAE', 'NOCTILIONIDAE', 'NYCTERIDAE',
       'HOMINIDAE', 'RHINOLOPHIDAE', 'RHINOPOMATIDAE', 'CEBIDAE',
       'SOLENODONTIDAE', 'TAPIRIDAE', 'THYROPTERIDAE', 'SYLVIIDAE',
       'MELIPHAGIDAE', 'EMBERIZIDAE', 'ACANTHISITTIDAE', 'ACANTHIZIDAE',
       'STURNIDAE', 'FURNARIIDAE', 'RHINOCRYPTIDAE', 'TIMALIIDAE',
       'AEGITHALIDAE', 'AEGITHINIDAE', 'NECTARINIIDAE', 'ICTERIDAE',
       'TYRANNIDAE', 'PTILONORHYNCHIDAE', 'ALAUDIDAE', 'PACHYCEPHALIDAE',
       'COLUMBIDAE', 'TURDIDAE', 'PYCNONOTIDAE', 'HIRUNDINIDAE',
       'ESTRILDIDAE', 'PETROICIDAE', 'CARDINALIDAE', 'PLOCEIDAE',
       'COTINGIDAE', 'MALURIDAE', 'EUPETIDAE', 'THRAUPIDAE', 'VIDUIDAE',
       'REMIZIDAE', 'MOTACILLIDAE', 'PIPRIDAE', 'CISTICOLIDAE',
       'ZOSTEROPIDAE', 'CORVIDAE', 'MONARCHIDAE', 'VANGIDAE', 'ARTAMIDAE',
       'PARADISAEIDAE', 'ATRICHORNITHIDAE', 'PARIDAE', 'PARULIDAE',
       'THAMNOPHILIDAE', 'PLATYSTEIRIDAE', 'BOMBYCILLIDAE', 'MUSCICAPIDAE',
       'FRINGILLIDAE', 'CALLAEATIDAE', 'EURYLAIMIDAE', 'CAMPEPHAGIDAE',
       'DENDROCOLAPTIDAE', 'TROGLODYTIDAE', 'CERTHIIDAE', 'MOHOIDAE',
       'DICRURIDAE', 'FORMICARIIDAE', 'CHLOROPSEIDAE', 'MIMIDAE',
       'CINCLOSOMATIDAE', 'CINCLIDAE', 'CLIMACTERIDAE', 'CNEMOPHILIDAE',
       'COEREBIDAE', 'COLLURICINCLIDAE', 'CONOPOPHAGIDAE', 'CORCORACIDAE',
       'LANIIDAE', 'CRACTICIDAE', 'VIREONIDAE', 'NEOSITTIDAE',
       'DASYORNITHIDAE', 'DICAEIDAE', 'DONACOBIIDAE', 'MALACONOTIDAE',
       'DULIDAE', 'FALCUNCULIDAE', 'PASSERIDAE', 'ORTHONYCHIDAE',
       'IRENIDAE', 'MACHAERIRHYNCHIDAE', 'MELANOCHARITIDAE', 'MENURIDAE',
       'POLIOPTILIDAE', 'PHILEPITTIDAE', 'ORIOLIDAE', 'PARDALOTIDAE',
       'PEUCEDRAMIDAE', 'PICATHARTIDAE', 'PITTIDAE', 'PITYRIASEIDAE',
       'POMATOSTOMIDAE', 'PROMEROPIDAE', 'PRUNELLIDAE', 'REGULIIDAE',
       'RHABDORNITHIDAE', 'RHIPIDURIDAE', 'SAPAYOAIDAE', 'SITTIDAE',
       'TURNAGRIDAE', 'UROCYNCHRAMIDAE', 'PubmedHits')


predictorsNames = predictorsNames[!predictorsNames %in% c('Activity_Diurnal', 'Activity_Nocturnal', 'BodyMass_SpecLevel',
                                                          'Diet_Fruit', "Diet_Inv","Diet_Nect","Diet_PlantO", "Diet_Scav",
                                                          "Diet_Seed", "Diet_Vect","Diet_Vend", "Diet_Vfish", "Diet_Vunk",
                                                          "ForStrat_aerial", "ForStrat_aquatic","ForStrat_arboreal", "ForStrat_ground", 
                                                          'Crops_count', "Crops_max","Crops_mean", "Crops_median", "Crops_min","Crops_range",
                                                          "Crops_std","LandUse_count",'LandUse_majority', "LandUse_max","LandUse_mean",
                                                          "LandUse_median","LandUse_min","LandUse_range","LandUse_std","Livestock_count",
                                                          "Livestock_majority","Livestock_max","Livestock_mean","Livestock_median","Livestock_min",
                                                          "Livestock_range","Livestock_std","MetRate_W_log","BodyMass_log",
                                                          'TotalBinary', 'Test', 'Class','Family', 'Order','Data.Richness', 
                                                          'PubmedHits', "BodyMass", "Metabolic.Rate",
                                                          "Distribution.Area", "Mean.Temperature", "Mean.Human.population",
                                                          "HabitatBreadth", "bdiversity_min", "bdiversity_std", "mdiversity_min","mdiversity_std", 
                                                          "DELPHINIDAE", "sp", "BALAENIDAE", "BALAENOPTERIDAE", "ZIPHIIDAE",
                                                          "NEOBALAENIDAE", "CISTUGIDAE", "MONODONTIDAE", "ESCHRICHTIIDAE",
                                                          "INIIDAE", "PHYSETERIDAE", "PHOCOENIDAE", 
                                                          "PLATANISTIDAE","MINIOPTERIDAE", 
                                                          
                                                          "Bio12_range","Bio1_range","Bio3_range", 'HuPop_range',
                                                          "Slope_range", "bdiversity_range", "mdiversity_range",
                                                          "Mosquitoes_range_log","Ticks_range_log","Bio12_majority",
                                                          
                                                          "Bio1_majority","Bio3_majority", 'HuPop_majority',
                                                         "Slope_majority_log", "bdiversity_majority", "mdiversity_majority",
                                                         "Mosquitoes_majority","Ticks_majority",
                                                         
                                                          "Bio1_max","Bio3_max", 'HuPop_max',
                                                         "Slope_max_log", "bdiversity_max", "mdiversity_max",
                                                         "Mosquitoes_max","Ticks_max",
                                                         
                                                          "Bio1_min","Bio3_min", 'HuPop_min',
                                                         "Slope_min_log", "bdiversity_min", "mdiversity_min",
                                                         "Mosquitoes_min","Ticks_min",
                                                         
                                                          "Bio1_std","Bio3_std", 'HuPop_std',
                                                         "Slope_std_log", "bdiversity_std", "mdiversity_std",
                                                         "Mosquitoes_std","Ticks_std",
                                                         
                                                          'Shape_Length_log', "Slope_mean",
                                                         
                                                          "Bio12_max","Bio12_min","Bio12_std",
                                                         "Slope_min","Slope_std", 
                                                         "Mosquitoes_min_log", "Mosquitoes_std_log",
                                                          "Ticks_max_log", "Ticks_std_log", 
                                                         'HuPop_mean')]

predictorsNames = predictorsNames[!predictorsNames %in% habitats]

#predictorsNames = c(predictorsNames, 'LVSTD_DS', 'LUS_DS')
predictorsNames = c(predictorsNames, 'LVSTD_DS', 'LandUse_collapsed')

# %%
outcomeName <- 'Group6Binary'

# %%
predictorsNames
# Out:
#   [1] "Bio12_mean"           "Bio1_mean"            "Bio3_mean"
#   [4] "Crops_majority"       "Mosquitoes_mean"      "Ticks_mean"
#   [7] "bdiversity_mean"      "centroidY"            "maxlat"
#  [10] "mdiversity_mean"      "minlat"               "minlong"
#  [13] "Shape_Area_log"       "centroidX_log"        "maxlong_log"
#  [16] "MaxDiet"              "ForStrategy"          "ActivityTime"
#  [19] "Body_Temperature"     "IUCN.Status"          "Population.trend"
#  [22] "BodyMass_ln"          "Metabolic_Rate_ln"    "Habitat_Breadth_sqrt"
#  [25] "PubmedHits_ln"        "HuPop_mean_log"       "SLP_DS"
#  [28] "PTEROPODIDAE"         "BOVIDAE"              "CERVIDAE"
#  [31] "ATELIDAE"             "PHYLLOSTOMIDAE"       "FURIPTERIDAE"
#  [34] "SORICIDAE"            "HIPPOSIDERIDAE"       "ANTILOCAPRIDAE"
#  [37] "VESPERTILIONIDAE"     "ERINACEIDAE"          "MOLOSSIDAE"
#  [40] "SUIDAE"               "EMBALLONURIDAE"       "CALLITRICHIDAE"
#  [43] "CAMELIDAE"            "MEGADERMATIDAE"       "TAYASSUIDAE"
#  [46] "RHINOCEROTIDAE"       "NATALIDAE"            "CERCOPITHECIDAE"
#  [49] "HIPPOPOTAMIDAE"       "TALPIDAE"             "CRASEONYCTERIDAE"
#  [52] "EQUIDAE"              "GIRAFFIDAE"           "TRAGULIDAE"
#  [55] "MORMOOPIDAE"          "MOSCHIDAE"            "MYSTACINIDAE"
#  [58] "MYZOPODIDAE"          "NOCTILIONIDAE"        "NYCTERIDAE"
#  [61] "HOMINIDAE"            "RHINOLOPHIDAE"        "RHINOPOMATIDAE"
#  [64] "CEBIDAE"              "SOLENODONTIDAE"       "TAPIRIDAE"
#  [67] "THYROPTERIDAE"        "SYLVIIDAE"            "MELIPHAGIDAE"
#  [70] "EMBERIZIDAE"          "ACANTHISITTIDAE"      "ACANTHIZIDAE"
#  [73] "STURNIDAE"            "FURNARIIDAE"          "RHINOCRYPTIDAE"
#  [76] "TIMALIIDAE"           "AEGITHALIDAE"         "AEGITHINIDAE"
#  [79] "NECTARINIIDAE"        "ICTERIDAE"            "TYRANNIDAE"
#  [82] "PTILONORHYNCHIDAE"    "ALAUDIDAE"            "PACHYCEPHALIDAE"
#  [85] "COLUMBIDAE"           "TURDIDAE"             "PYCNONOTIDAE"
#  [88] "HIRUNDINIDAE"         "ESTRILDIDAE"          "PETROICIDAE"
#  [91] "CARDINALIDAE"         "PLOCEIDAE"            "COTINGIDAE"
#  [94] "MALURIDAE"            "EUPETIDAE"            "THRAUPIDAE"
#  [97] "VIDUIDAE"             "REMIZIDAE"            "MOTACILLIDAE"
# [100] "PIPRIDAE"             "CISTICOLIDAE"         "ZOSTEROPIDAE"
# [103] "CORVIDAE"             "MONARCHIDAE"          "VANGIDAE"
# [106] "ARTAMIDAE"            "PARADISAEIDAE"        "ATRICHORNITHIDAE"
# [109] "PARIDAE"              "PARULIDAE"            "THAMNOPHILIDAE"
# [112] "PLATYSTEIRIDAE"       "BOMBYCILLIDAE"        "MUSCICAPIDAE"
# [115] "FRINGILLIDAE"         "CALLAEATIDAE"         "EURYLAIMIDAE"
# [118] "CAMPEPHAGIDAE"        "DENDROCOLAPTIDAE"     "TROGLODYTIDAE"
# [121] "CERTHIIDAE"           "MOHOIDAE"             "DICRURIDAE"
# [124] "FORMICARIIDAE"        "CHLOROPSEIDAE"        "MIMIDAE"
# [127] "CINCLOSOMATIDAE"      "CINCLIDAE"            "CLIMACTERIDAE"
# [130] "CNEMOPHILIDAE"        "COEREBIDAE"           "COLLURICINCLIDAE"
# [133] "CONOPOPHAGIDAE"       "CORCORACIDAE"         "LANIIDAE"
# [136] "CRACTICIDAE"          "VIREONIDAE"           "NEOSITTIDAE"
# [139] "DASYORNITHIDAE"       "DICAEIDAE"            "DONACOBIIDAE"
# [142] "MALACONOTIDAE"        "DULIDAE"              "FALCUNCULIDAE"
# [145] "PASSERIDAE"           "ORTHONYCHIDAE"        "IRENIDAE"
# [148] "MACHAERIRHYNCHIDAE"   "MELANOCHARITIDAE"     "MENURIDAE"
# [151] "POLIOPTILIDAE"        "PHILEPITTIDAE"        "ORIOLIDAE"
# [154] "PARDALOTIDAE"         "PEUCEDRAMIDAE"        "PICATHARTIDAE"
# [157] "PITTIDAE"             "PITYRIASEIDAE"        "POMATOSTOMIDAE"
# [160] "PROMEROPIDAE"         "PRUNELLIDAE"          "REGULIIDAE"
# [163] "RHABDORNITHIDAE"      "RHIPIDURIDAE"         "SAPAYOAIDAE"
# [166] "SITTIDAE"             "TURNAGRIDAE"          "UROCYNCHRAMIDAE"
# [169] "LVSTD_DS"             "LandUse_collapsed"

# %%
length(predictorsNames)
# Out:
# [1] 170

# %%
set.seed(100)
Group1.total.tc5.lr0005 <- gbm.step(data = model.data,
                                   gbm.x = predictorsNames,
                                   gbm.y = outcomeName,
                                   family = "bernoulli",
                                   tree.complexity = 5,
                                   learning.rate = 0.001,
                                   bag.fraction = 0.5, 
                                   cv = 10)
# Out:
#
#  GBM STEP - version 2.9
#
# Performing cross-validation optimisation of a boosted regression tree model
# for NA and using a family of bernoulli
# Using 8148 observations and 170 predictors
# creating 10 initial models of 50 trees
#
#  folds are stratified by prevalence
# total mean deviance =  0.0344
# tolerance is fixed at  0
# ntrees resid. dev.
# 50    0.0323
# now adding trees...
# 100   0.0313
# 150   0.0307
# 200   0.0302
# 250   0.0299
# 300   0.0295
# 350   0.0293
# 400   0.029
# 450   0.0289
# 500   0.0287
# 550   0.0286
# 600   0.0284
# 650   0.0283
# 700   0.0282
# 750   0.0281
# 800   0.028
# 850   0.0279
# 900   0.0278
# 950   0.0277
# 1000   0.0277
# 1050   0.0276
# 1100   0.0276
# 1150   0.0275
# 1200   0.0275
# 1250   0.0274
# 1300   0.0274
# 1350   0.0274
# 1400   0.0274
# 1450   0.0273
# 1500   0.0273
# 1550   0.0273
# 1600   0.0273
# 1650   0.0272
# 1700   0.0272
# 1750   0.0272
# 1800   0.0272
# 1850   0.0272
# 1900   0.0272
# 1950   0.0272
# 2000   0.0272
# 2050   0.0272
# 2100   0.0272
# 2150   0.0272
# 2200   0.0272
# 2250   0.0272
# 2300   0.0272
# 2350   0.0272
# 2400   0.0272
# 2450   0.0272
# fitting final gbm model with a fixed number of 2050 trees for NA
# mean total deviance = 0.034
# mean residual deviance = 0.009
#
# estimated cv deviance = 0.027 ; se = 0.002
#
# training data correlation = 0.821
# cv correlation =  0.201 ; se = 0.091
#
# training data AUC score = 1
# cv AUC score = 0.906 ; se = 0.028
#
# elapsed time -  0.51 minutes
# Plot with title "NA, d - 5, lr - 0.001"

# %%
#for (i in predictorsNames){
#    print (i)
#    a = which( colnames(model.data)== i )
#    print (a)
#}

# %%
summary(Group1.total.tc5.lr0005)
# Out:
#                                       var           rel.inf
# BodyMass_ln                   BodyMass_ln   16.393318613395
# minlat                             minlat  11.3306733120877
# Shape_Area_log             Shape_Area_log  9.29707375734885
# maxlat                             maxlat  7.72799234362752
# HuPop_mean_log             HuPop_mean_log  7.37934715831183
# minlong                           minlong  5.88513429856599
# ForStrategy                   ForStrategy  5.71562738993034
# Ticks_mean                     Ticks_mean  3.83234864414809
# Metabolic_Rate_ln       Metabolic_Rate_ln  3.63345308204239
# PubmedHits_ln               PubmedHits_ln  3.54110719804824
# Bio3_mean                       Bio3_mean    3.197380329182
# bdiversity_mean           bdiversity_mean  2.97973068375299
# centroidY                       centroidY  2.53746672191912
# Bio1_mean                       Bio1_mean   2.0637723414545
# Mosquitoes_mean           Mosquitoes_mean  1.58037247343885
# RHINOLOPHIDAE               RHINOLOPHIDAE  1.31628919627421
# Bio12_mean                     Bio12_mean  1.21509246597089
# centroidX_log               centroidX_log  1.21438591105664
# IUCN.Status                   IUCN.Status  1.16000381006659
# MaxDiet                           MaxDiet  1.11264944179676
# maxlong_log                   maxlong_log  1.01230139169289
# LVSTD_DS                         LVSTD_DS 0.860962925306503
# mdiversity_mean           mdiversity_mean 0.853309609463874
# SLP_DS                             SLP_DS 0.663358178778344
# Body_Temperature         Body_Temperature 0.603900918381934
# LandUse_collapsed       LandUse_collapsed  0.55264971238808
# Habitat_Breadth_sqrt Habitat_Breadth_sqrt 0.508054169997682
# VESPERTILIONIDAE         VESPERTILIONIDAE 0.442978088275302
# SUIDAE                             SUIDAE 0.348148270231589
# Population.trend         Population.trend 0.262462463476739
# ...                                   ...               ...
# DASYORNITHIDAE             DASYORNITHIDAE                 0
# DICAEIDAE                       DICAEIDAE                 0
# DONACOBIIDAE                 DONACOBIIDAE                 0
# MALACONOTIDAE               MALACONOTIDAE                 0
# DULIDAE                           DULIDAE                 0
# FALCUNCULIDAE               FALCUNCULIDAE                 0
# PASSERIDAE                     PASSERIDAE                 0
# ORTHONYCHIDAE               ORTHONYCHIDAE                 0
# IRENIDAE                         IRENIDAE                 0
# MACHAERIRHYNCHIDAE     MACHAERIRHYNCHIDAE                 0
# MELANOCHARITIDAE         MELANOCHARITIDAE                 0
# MENURIDAE                       MENURIDAE                 0
# POLIOPTILIDAE               POLIOPTILIDAE                 0
# PHILEPITTIDAE               PHILEPITTIDAE                 0
# ORIOLIDAE                       ORIOLIDAE                 0
# PARDALOTIDAE                 PARDALOTIDAE                 0
# PEUCEDRAMIDAE               PEUCEDRAMIDAE                 0
# PICATHARTIDAE               PICATHARTIDAE                 0
# PITTIDAE                         PITTIDAE                 0
# PITYRIASEIDAE               PITYRIASEIDAE                 0
# POMATOSTOMIDAE             POMATOSTOMIDAE                 0
# PROMEROPIDAE                 PROMEROPIDAE                 0
# PRUNELLIDAE                   PRUNELLIDAE                 0
# REGULIIDAE                     REGULIIDAE                 0
# RHABDORNITHIDAE           RHABDORNITHIDAE                 0
# RHIPIDURIDAE                 RHIPIDURIDAE                 0
# SAPAYOAIDAE                   SAPAYOAIDAE                 0
# SITTIDAE                         SITTIDAE                 0
# TURNAGRIDAE                   TURNAGRIDAE                 0
# UROCYNCHRAMIDAE           UROCYNCHRAMIDAE                 0
# plot without title

# %%
print(Group1.total.tc5.lr0005)
# Out:
# gbm::gbm(formula = y.data ~ ., distribution = as.character(family),
#     data = x.data, weights = site.weights, var.monotone = var.monotone,
#     n.trees = target.trees, interaction.depth = tree.complexity,
#     shrinkage = learning.rate, bag.fraction = bag.fraction, verbose = FALSE)
# A gradient boosted model with bernoulli loss function.
# 2050 iterations were performed.
# There were 170 predictors of which 36 had non-zero influence.

# %%
plot.gbm(Group1.total.tc5.lr0005, 'Bio1_mean')
# Out:
# plot without title

# %%
ranks = relative.influence(Group1.total.tc5.lr0005, scale. = 'TRUE', sort. = 'TRUE')
a = as.data.frame(ranks, col.names = , optional = FALSE)
a = setDT(a, keep.rownames = TRUE)[]
colnames(a) = c('Variable','influence')
b = a
for (i in b$Variable){
    margianleffects = plot.gbm(Group1.total.tc5.lr0005, i.var = i,n.plots=3, 
                           write.title = T, return.grid  = T,
                           show.contrib = T,y.label="Marginal effect on Host")
    filename = paste("Outputs/PartialDependence2/", i,'Group6','.csv', sep="")
    write.csv(margianleffects, file = filename)    
}
# Out:
# n.trees not given. Using 2050 trees.

# %%
write.csv(a, 'Outputs/PartialDependence2/Ranks_group6.csv')

# %%
head(a, 50)
# Out:
#                Variable    influence
# 1           BodyMass_ln 1.0000000000
# 2                minlat 0.6911763005
# 3        Shape_Area_log 0.5671257893
# 4                maxlat 0.4714110990
# 5        HuPop_mean_log 0.4501435818
# 6               minlong 0.3589959079
# 7           ForStrategy 0.3486559082
# 8            Ticks_mean 0.2337750357
# 9     Metabolic_Rate_ln 0.2216423146
# 10        PubmedHits_ln 0.2160091731
# 11            Bio3_mean 0.1950416755
# 12      bdiversity_mean 0.1817649467
# 13            centroidY 0.1547866409
# 14            Bio1_mean 0.1258910651
# 15      Mosquitoes_mean 0.0964034501
# 16        RHINOLOPHIDAE 0.0802942484
# 17           Bio12_mean 0.0741212011
# 18        centroidX_log 0.0740781009
# 19          IUCN.Status 0.0707607677
# 20              MaxDiet 0.0678721294
# 21          maxlong_log 0.0617508520
# 22             LVSTD_DS 0.0525191357
# 23      mdiversity_mean 0.0520522799
# 24               SLP_DS 0.0404651550
# 25     Body_Temperature 0.0368382347
# 26    LandUse_collapsed 0.0337118875
# 27 Habitat_Breadth_sqrt 0.0309915388
# 28     VESPERTILIONIDAE 0.0270218678
# 29               SUIDAE 0.0212372051
# 30     Population.trend 0.0160103314
# 31       HIPPOSIDERIDAE 0.0155194194
# 32         ActivityTime 0.0124795576
# 33          ESTRILDIDAE 0.0096005635
# 34             TURDIDAE 0.0067714745
# 35         PTEROPODIDAE 0.0021290256
# 36             CERVIDAE 0.0009982797
# 37      UROCYNCHRAMIDAE 0.0000000000
# 38          TURNAGRIDAE 0.0000000000
# 39             SITTIDAE 0.0000000000
# 40          SAPAYOAIDAE 0.0000000000
# 41         RHIPIDURIDAE 0.0000000000
# 42      RHABDORNITHIDAE 0.0000000000
# 43           REGULIIDAE 0.0000000000
# 44          PRUNELLIDAE 0.0000000000
# 45         PROMEROPIDAE 0.0000000000
# 46       POMATOSTOMIDAE 0.0000000000
# 47        PITYRIASEIDAE 0.0000000000
# 48             PITTIDAE 0.0000000000
# 49        PICATHARTIDAE 0.0000000000
# 50        PEUCEDRAMIDAE 0.0000000000

# %%
#Group1.simp = gbm.simplify(Group1.total.tc5.lr0005,)# n.drops = 5)

# %%
#find.int <- gbm.interactions(Group1.total.tc5.lr0005)
#find.int$interactions

# %%
#gbm.perspec(Group1.total.tc5.lr0005, 29, 28, y.range=c(15,20), z.range=c(0,0.6))

# %%
preds <- predict.gbm(Group1.total.tc5.lr0005, model.data,n.trees=Group1.total.tc5.lr0005$gbm.call$best.trees, type="response")
calc.deviance(obs=model.data$Group6Binary, pred=preds, calc.mean=TRUE)
# Out:
# [1] 0.009383202

# %%
d <- cbind(model.data$Group6Binary, preds)
pres <- d[d[,1]==1, 2]
abs <- d[d[,1]==0, 2]
e <- evaluate(p=pres, a=abs)
e
# Out:
# class          : ModelEvaluation
# n presences    : 20
# n absences     : 8128
# AUC            : 0.999594
# cor            : 0.8214045
# max TPR+TNR at : 0.02452537

# %%
model.data$PredictionProbability  = preds
write.csv(model.data, file = "Outputs/Predictions_R_Group6.csv")

# %% [markdown]
# ## Holdout dataset and Cross Validation

# %%
library(caTools)
model.data$spl=sample.split(model.data$Group6Binary,SplitRatio=0.8)
train=subset(model.data, model.data$spl==TRUE)
test=subset(model.data, model.data$spl==FALSE)
nrow(train)
nrow(test)
table(model.data$Group6Binary)
table(train$Group6Binary)
table(test$Group6Binary)
# Out:
# [1] 6517
# [1] 1629
#    0    1
# 8126   20
#    0    1
# 6501   16
#    0    1
# 1625    4

# %%
set.seed(100)
Group1.total.tc5.lr0005 <- gbm.step(data = train,
                                   gbm.x = predictorsNames,
                                   gbm.y = outcomeName,
                                   family = "bernoulli",
                                   tree.complexity = 5,
                                   learning.rate = 0.001,
                                   bag.fraction = 0.5, 
                                   cv = 10, 
                                   max.trees = 20000)
# Out:
#
#  GBM STEP - version 2.9
#
# Performing cross-validation optimisation of a boosted regression tree model
# for NA and using a family of bernoulli
# Using 6517 observations and 170 predictors
# creating 10 initial models of 50 trees
#
#  folds are stratified by prevalence
# total mean deviance =  0.0344
# tolerance is fixed at  0
# ntrees resid. dev.
# 50    0.0333
# now adding trees...
# 100   0.0326
# 150   0.032
# 200   0.0318
# 250   0.0316
# 300   0.0313
# 350   0.0312
# 400   0.031
# 450   0.0309
# 500   0.0308
# 550   0.0307
# 600   0.0306
# 650   0.0305
# 700   0.0304
# 750   0.0304
# 800   0.0303
# 850   0.0303
# 900   0.0302
# 950   0.0302
# 1000   0.0301
# 1050   0.0301
# 1100   0.0301
# 1150   0.0301
# 1200   0.0301
# 1250   0.0301
# 1300   0.0301
# 1350   0.0301
# 1400   0.0301
# 1450   0.0301
# 1500   0.0301
# 1550   0.0301
# 1600   0.0301
# 1650   0.0301
# 1700   0.0301
# 1750   0.0301
# 1800   0.0301
# 1850   0.0301
# fitting final gbm model with a fixed number of 1250 trees for NA
# mean total deviance = 0.034
# mean residual deviance = 0.012
#
# estimated cv deviance = 0.03 ; se = 0.003
#
# training data correlation = 0.795
# cv correlation =  0.149 ; se = 0.067
#
# training data AUC score = 1
# cv AUC score = 0.834 ; se = 0.046
#
# elapsed time -  0.38 minutes
# Plot with title "NA, d - 5, lr - 0.001"

# %%
print(Group1.total.tc5.lr0005)
# Out:
# gbm::gbm(formula = y.data ~ ., distribution = as.character(family),
#     data = x.data, weights = site.weights, var.monotone = var.monotone,
#     n.trees = target.trees, interaction.depth = tree.complexity,
#     shrinkage = learning.rate, bag.fraction = bag.fraction, verbose = FALSE)
# A gradient boosted model with bernoulli loss function.
# 1250 iterations were performed.
# There were 170 predictors of which 36 had non-zero influence.

# %%
preds2 <- predict.gbm(Group1.total.tc5.lr0005, 
                     test[,predictorsNames],
                     n.trees=Group1.total.tc5.lr0005$gbm.call$best.trees,
                     type="response")

calc.deviance(obs=test$Group6Binary, pred=preds2, calc.mean=TRUE)
# Out:
# [1] 0.02514015

# %%
d <- cbind(test$Group6Binary, preds2)
pres <- d[d[,1]==1, 2]
abs <- d[d[,1]==0, 2]
e <- evaluate(p=pres, a=abs)
e
# Out:
# class          : ModelEvaluation
# n presences    : 4
# n absences     : 1625
# AUC            : 0.992
# cor            : 0.3304401
# max TPR+TNR at : 0.00487571

# %%
preds2 <- predict.gbm(Group1.total.tc5.lr0005, 
                     model.data[,predictorsNames],
                     n.trees=Group1.total.tc5.lr0005$gbm.call$best.trees,
                     type="response")

# %%
model.data$PredictionProbability  = preds2
write.csv(model.data, file = "Outputs2/Predictions_R_Group6.csv")

# %%
summary(Group1.total.tc5.lr0005)
# Out:
#                      var                  rel.inf
# BodyMass_ln          BodyMass_ln          16.8105354
# minlat               minlat               10.2474774
# minlong              minlong               9.2770254
# ForStrategy          ForStrategy           8.9636628
# Shape_Area_log       Shape_Area_log        8.1378103
# PubmedHits_ln        PubmedHits_ln         6.2571451
# HuPop_mean_log       HuPop_mean_log        4.6904265
# maxlat               maxlat                4.5154116
# Metabolic_Rate_ln    Metabolic_Rate_ln     4.0440504
# centroidY            centroidY             3.6577178
# Bio3_mean            Bio3_mean             2.6632735
# LandUse_collapsed    LandUse_collapsed     2.3957878
# Mosquitoes_mean      Mosquitoes_mean       2.2370400
# Ticks_mean           Ticks_mean            1.9240161
# Bio12_mean           Bio12_mean            1.4655972
# centroidX_log        centroidX_log         1.4526077
# Bio1_mean            Bio1_mean             1.3381217
# IUCN.Status          IUCN.Status           1.3346566
# LVSTD_DS             LVSTD_DS              1.0841365
# MaxDiet              MaxDiet               0.8908395
# mdiversity_mean      mdiversity_mean       0.8321184
# SLP_DS               SLP_DS                0.7813563
# Body_Temperature     Body_Temperature      0.7477255
# bdiversity_mean      bdiversity_mean       0.6929123
# RHINOLOPHIDAE        RHINOLOPHIDAE         0.5526572
# HIPPOSIDERIDAE       HIPPOSIDERIDAE        0.5474564
# VESPERTILIONIDAE     VESPERTILIONIDAE      0.5013412
# Habitat_Breadth_sqrt Habitat_Breadth_sqrt  0.4423533
# maxlong_log          maxlong_log           0.4044411
# Population.trend     Population.trend      0.3815292
# ...                  ...                  ...
# DASYORNITHIDAE       DASYORNITHIDAE       0
# DICAEIDAE            DICAEIDAE            0
# DONACOBIIDAE         DONACOBIIDAE         0
# MALACONOTIDAE        MALACONOTIDAE        0
# DULIDAE              DULIDAE              0
# FALCUNCULIDAE        FALCUNCULIDAE        0
# PASSERIDAE           PASSERIDAE           0
# ORTHONYCHIDAE        ORTHONYCHIDAE        0
# IRENIDAE             IRENIDAE             0
# MACHAERIRHYNCHIDAE   MACHAERIRHYNCHIDAE   0
# MELANOCHARITIDAE     MELANOCHARITIDAE     0
# MENURIDAE            MENURIDAE            0
# POLIOPTILIDAE        POLIOPTILIDAE        0
# PHILEPITTIDAE        PHILEPITTIDAE        0
# ORIOLIDAE            ORIOLIDAE            0
# PARDALOTIDAE         PARDALOTIDAE         0
# PEUCEDRAMIDAE        PEUCEDRAMIDAE        0
# PICATHARTIDAE        PICATHARTIDAE        0
# PITTIDAE             PITTIDAE             0
# PITYRIASEIDAE        PITYRIASEIDAE        0
# POMATOSTOMIDAE       POMATOSTOMIDAE       0
# PROMEROPIDAE         PROMEROPIDAE         0
# PRUNELLIDAE          PRUNELLIDAE          0
# REGULIIDAE           REGULIIDAE           0
# RHABDORNITHIDAE      RHABDORNITHIDAE      0
# RHIPIDURIDAE         RHIPIDURIDAE         0
# SAPAYOAIDAE          SAPAYOAIDAE          0
# SITTIDAE             SITTIDAE             0
# TURNAGRIDAE          TURNAGRIDAE          0
# UROCYNCHRAMIDAE      UROCYNCHRAMIDAE      0
# plot without title

# %%
ranks = relative.influence(Group1.total.tc5.lr0005, scale. = 'TRUE', sort. = 'TRUE')
a = as.data.frame(ranks, col.names = , optional = FALSE)
a = setDT(a, keep.rownames = TRUE)[]
colnames(a) = c('Variable','influence')
b = a
for (i in b$Variable){
    margianleffects = plot.gbm(Group1.total.tc5.lr0005, i.var = i,n.plots=3, 
                           write.title = T, return.grid  = T,
                           show.contrib = T,y.label="Marginal effect on Host")
    filename = paste("Outputs2/PartialDependence2/", i,'Group6','.csv', sep="")
    write.csv(margianleffects, file = filename)    
}
# Out:
# n.trees not given. Using 1250 trees.

# %%
write.csv(a, 'Outputs2/PartialDependence2/Ranks_group6.csv')
