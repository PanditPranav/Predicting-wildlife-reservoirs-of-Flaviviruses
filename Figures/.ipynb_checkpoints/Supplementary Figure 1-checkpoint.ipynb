# %%
import os as os
os.chdir('C:\Users\Falco\Desktop\directory\Predicting-wildlife-reservoirs-of-Flaviviruses')
import geopandas as gpd
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
% run Settings.py

# %%
g = pd.read_csv('Outputs2/PartialDependence2/Ranks_generic.csv')
#g2 = pd.read_csv('Outputs/PartialDependence/Ranks_group2.csv')

# %%
g = g.head(10)

# %%
#g2 = g2.head(8)

# %%
g.head(10)
# Out:
#    Unnamed: 0           Variable  influence
# 0           1     Shape_Area_log   1.000000
# 1           2             maxlat   0.923453
# 2           3      PubmedHits_ln   0.841291
# 3           4          centroidY   0.361992
# 4           5            MaxDiet   0.303828
# 5           6            minlong   0.260402
# 6           7   Population.trend   0.193490
# 7           8      centroidX_log   0.181989
# 8           9        BodyMass_ln   0.181132
# 9          10  Metabolic_Rate_ln   0.169548

# %% [markdown]
# plt.rcParams['figure.figsize'] = (12, 5)
#
# f, (ax1, ax2) = plt.subplots(1, 2)
#
# sns.barplot(x = 'influence', y = 'Variable', data= g1a, ax= ax1 )
# sns.barplot(x = 'influence', y = 'Variable', data= g2, ax= ax2 )
# ax2.set_yticklabels(g2names)
# ax1.set_yticklabels(g1names)
# ax1.set_xlabel('Relative influence')
# ax2.set_xlabel('Relative influence')
# ax1.set_title('YFV, ZIKV', )
# ax2.set_title('WNV, SLEV, USUV', )
# plt.suptitle('Feature importance', fontsize = 18)
# plt.tight_layout()
# plt.subplots_adjust(top=0.80)
# plt.show()
# #f.savefig('Outputs/Feature importance.png')

# %%
import glob

# %%
path = 'Outputs2/PartialDependence2/'
csvFiles = glob.glob(path + "*.csv")
frames_dict = {}

for files in csvFiles:
    name  = str(files).replace('.csv','')
    name  = str(name).replace("Outputs2/PartialDependence2\\", '')
    frames_dict[name] = pd.read_csv(files)
    #df.name = str(name).replace("Outputs/PartialDependence\\", '')
#list(frames_dict.keys())

# %%
a = frames_dict['Ranks_generic'].head(15)
a.set_index('Variable', inplace= True)
#datag1a = pd.read_csv('Outputs/dataGroup1a.csv')
datag = pd.read_csv('Outputs/PartialDependence2/GenericData_forPartial.csv')

# %%
a
# Out:
#                    Unnamed: 0  influence
# Variable
# Shape_Area_log              1   1.000000
# maxlat                      2   0.923453
# PubmedHits_ln               3   0.841291
# centroidY                   4   0.361992
# MaxDiet                     5   0.303828
# minlong                     6   0.260402
# Population.trend            7   0.193490
# centroidX_log               8   0.181989
# BodyMass_ln                 9   0.181132
# Metabolic_Rate_ln          10   0.169548
# minlat                     11   0.163382
# Mosquitoes_mean            12   0.156985
# Bio3_mean                  13   0.133190
# Ticks_mean                 14   0.126133
# maxlong_log                15   0.122864

# %%
x11 = frames_dict['Shape_Area_log_GenericFlavi']['Shape_Area_log']
y11 = frames_dict['Shape_Area_log_GenericFlavi']['y']

x22 = frames_dict['maxlat_GenericFlavi']['maxlat']
y22 = frames_dict['maxlat_GenericFlavi']['y']

x33 = frames_dict['PubmedHits_ln_GenericFlavi']['PubmedHits_ln']
y33 = frames_dict['PubmedHits_ln_GenericFlavi']['y']

x44 = frames_dict['centroidY_GenericFlavi']['centroidY']
y44 = frames_dict['centroidY_GenericFlavi']['y']

x66 = frames_dict['minlong_GenericFlavi']['minlong']
y66 = frames_dict['minlong_GenericFlavi']['y']

x88 = frames_dict['centroidX_log_GenericFlavi']['centroidX_log']
y88 = frames_dict['centroidX_log_GenericFlavi']['y']

x99 = frames_dict['BodyMass_ln_GenericFlavi']['BodyMass_ln']
y99 = frames_dict['BodyMass_ln_GenericFlavi']['y']

x100 = frames_dict['Metabolic_Rate_ln_GenericFlavi']['Metabolic_Rate_ln']
y100 = frames_dict['Metabolic_Rate_ln_GenericFlavi']['y']

# %%
frames_dict['MaxDiet_GenericFlavi']["MaxDiet"].unique()
# Out:
# array([nan, 'Fish', 'fruit', 'Inv', 'Nect', 'PlatO', 'Scav', 'Seed',
#        'Vect', 'vend', 'Vunk'], dtype=object)

# %%
frames_dict['SLP_DS_GenericFlavi']["SLP_DS"] = frames_dict['SLP_DSGroup1a']["SLP_DS"].str.replace(' to ', '-')
frames_dict['SLP_DS_GenericFlavi']["SLP_DS"] = frames_dict['SLP_DSGroup1a']["SLP_DS"].str.replace(' >', '>')
frames_dict['SLP_DS_GenericFlavi']["SLP_DS"] = frames_dict['SLP_DSGroup1a']["SLP_DS"].str.replace('no data', 'NA')
frames_dict['SLP_DS_GenericFlavi']["SLP_DS"] = frames_dict['SLP_DSGroup1a']["SLP_DS"].str.replace('Water', 'W')
frames_dict['SLP_DS_GenericFlavi']["SLP_DS"].unique()
# Out:
# array(['> 45', '0 to 0.5', '0.5 to 2', '16 to 30', '2 to 5', '30 to 45',
#        '5 to 8', '8 to 16', 'no data', 'W'], dtype=object)

# %%
datag.MaxDiet.unique()
# Out:
# array(['fruit', 'Fish', 'Inv', nan, 'Seed', 'Nect', 'PlatO', 'vend',
#        'Vunk', 'Vect', 'Scav'], dtype=object)

# %%
a.head(10)
# Out:
#                    Unnamed: 0  influence
# Variable
# Shape_Area_log              1   1.000000
# maxlat                      2   0.923453
# PubmedHits_ln               3   0.841291
# centroidY                   4   0.361992
# MaxDiet                     5   0.303828
# minlong                     6   0.260402
# Population.trend            7   0.193490
# centroidX_log               8   0.181989
# BodyMass_ln                 9   0.181132
# Metabolic_Rate_ln          10   0.169548

# %%
datag['Population.trend'].unique()
# Out:
# array(['decreasing', 'stable', 'unknown', '0', 'increasing'], dtype=object)

# %%
#g1names= ['Pubmed hits (log)\nnumber of citations','Distribution area , 'Northern bound$^\circ$',
#          'Eastern bound$^\circ$', 'Centroid latitude$^\circ$', 'Diet preference',
#          'Body mass (log)\ng','Metabolic rate (log) ', 'Population Trend', 'Isothermality']

#g1names= ['log distribution area \n($km^2$)','northernmost bound$^\circ$','log PubMed hits',
#          'centroid latitude$^\circ$', 'diet preference','westernmost bound$^\circ$',
#          'log body mass\n(g)','log metabolic rate\n($Wg^-1$)', 'log centroid longitude$^\circ$',
#         'isothermality']

g1names= ['log distribution area \n($km^2$)','northernmost bound$^\circ$','log PubMed hits',
          'centroid latitude$^\circ$', 'diet preference','westernmost bound$^\circ$',
          'population trend', 'log centroid longitude$^\circ$','log body mass\n(g)','log metabolic rate\n($Wg^-1$)',]

plt.rcParams['font.size'] = 10
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 8
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['figure.figsize'] = (16, 9)

sns.set_style('white')
#fig = plt.figure(figsize=(12,5), dpi=300)
f, ((ax1, ax2, ax3, ax4, ax5),(ax6, ax7, ax8, ax9, ax10)) = plt.subplots(2, 5)
alpha = 0.2


ax1.plot(x11, y11)
ax2.plot(x22, y22)
ax3.plot(x33, y33)
ax4.plot(x44, y44)

sns.swarmplot(x="MaxDiet", y="y", data=frames_dict['MaxDiet_GenericFlavi'],
              ax = ax5, size  = 10, color='b',
             order = ['nan', 'Fish', 'fruit', 'Inv', 'Nect', 'PlatO', 'Scav', 'Seed',
                      'Vect', 'vend', 'Vunk'])
ax6.plot(x66, y66)
#ax7.plot(x77, y77)
sns.swarmplot(x="Population.trend", y="y", data=frames_dict['Population.trendGroup4'],
              ax = ax7, size  = 10, color='b',
             order = ['stable','decreasing', 'increasing', 'unknown'])

ax8.plot(x88, y88)
ax9.plot(x99, y99)
ax8.plot(x88, y88, color = 'b')
ax10.plot(x100, y100)


ax1.set_xlabel(g1names[0]); ax2.set_xlabel(g1names[1]); ax3.set_xlabel(g1names[2]);ax4.set_xlabel(g1names[3]);
ax5.set_xlabel(g1names[4]); ax6.set_xlabel(g1names[5]); ax7.set_xlabel(g1names[6]);ax8.set_xlabel(g1names[7]);
ax9.set_xlabel(g1names[8]); ax10.set_xlabel(g1names[9])

ax1.set_ylabel('partial dependence of variable on prediction')
ax6.set_ylabel('partial dependence of variable on prediction')
ax1.set_title('Rank 1', fontsize = 11)
ax2.set_title('Rank 2', fontsize = 11)
ax3.set_title('Rank 3', fontsize = 11)
ax4.set_title('Rank 4', fontsize = 11)
ax5.set_title('Rank 5', fontsize = 11)
ax6.set_title('Rank 6', fontsize = 11)
ax7.set_title('Rank 7', fontsize = 11)
ax8.set_title('Rank 8', fontsize = 11)
ax9.set_title('Rank 9', fontsize = 11)
ax10.set_title('Rank 10', fontsize = 11)



ax11 = ax1.twinx()
ax11.hist(datag.Shape_Area_log.dropna(), alpha=alpha, color='green')

ax22 = ax2.twinx()
ax22.hist(datag.maxlat.dropna(), alpha=alpha, color='green')

ax33 = ax3.twinx()
ax33.hist(datag.PubmedHits_ln.dropna(), alpha=alpha, color='green')

ax44 = ax4.twinx()
ax44.hist(datag.centroidY.dropna(), alpha = alpha, color = 'green')

ax55 = ax5.twinx()
sns.countplot(datag.MaxDiet.dropna(),ax = ax55,alpha=alpha, color='green', 
             order = ['nan', 'Fish', 'fruit', 'Inv', 'Nect', 'PlatO', 'Scav', 'Seed',
                      'Vect', 'vend', 'Vunk'])

ax66 = ax6.twinx()
ax66.hist(datag.minlong.dropna(), alpha = alpha, color = 'green')

ax66.set_ylabel('Partial dependence')

ax77 = ax7.twinx()
sns.countplot(datag['Population.trend'].dropna(),ax = ax77,alpha=alpha, color='green', 
             order = ['stable','decreasing', 'increasing', 'unknown'])
#ax77.hist(datag.BodyMass_ln.dropna(), alpha = alpha, color = 'green')

ax88 = ax8.twinx()
ax88.hist(datag.centroidX_log.dropna(), alpha = alpha, color = 'green')

ax99 = ax9.twinx()
ax99.hist(datag.BodyMass_ln.dropna(), alpha = alpha, color = 'green')

ax100 = ax10.twinx()
ax100.hist(datag.Metabolic_Rate_ln.dropna(), alpha = alpha, color = 'green')
ax100.set_ylabel('number of species')
ax55.set_ylabel('number of species')

ax5.tick_params(axis='x', which='minor', labelsize=6,)
for tick in ax5.get_xticklabels():
    tick.set_rotation(90)
    
ax7.tick_params(axis='x', which='minor', labelsize=6,)
for tick in ax7.get_xticklabels():
    tick.set_rotation(90)
    
#ax5.set_xticklabels(lug1.Number.tolist(),)

#plt.suptitle('Trait profile for ZIKV and YFV', fontsize = 16)
plt.tight_layout()
#plt.subplots_adjust(top=0.85)
plt.show()
f.savefig('Outputs2/Generic_Partial_dependence.png')
f.savefig('C:\Users\Falco\Desktop\directory\Flavivirus Paper\Final Submission\Revision\pd_generic.png', dpi = 600)
